# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
import pandas as pd
import os
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## word-level speaker related feature extraction

# %%
import itertools
import torch

def load_pretrained_model(config, pretrained_path, ):
    pre_state = torch.load(pretrained_path)
#     fine_tuned_params = ['output.weight', 'output.bias']
    pre_trained_state = {k: v for k, v in pre_state.items()}

    new_si_model = config['model_class'](config)
    new_state = new_si_model.state_dict()
    new_state.update(pre_trained_state)
    new_si_model.load_state_dict(new_state)  
    
    for param in new_si_model.parameters():
        param.requires_grad = False
        
#     for param in itertools.chain(new_si_model.output.parameters()):
#         param.requires_grad = True
    return new_si_model

# %%
import honk_sv.train as hk
from honk_sv import model as mod

# %%
dataframe_dir = '/home/muncok/DL/dataset/SV_sets/dataframes/'
data_dir = '/home/muncok/DL/dataset/SV_sets/speech_commands/'
command_df = pd.read_pickle(os.path.join(dataframe_dir,'Command_Dataframe.pkl'))

# %%
pick_words = ["yes", "no", "up", "down"]

# %%
#TODO: correct splits
all_spks = command_df.spk.unique()
all_words= command_df.sent.unique()
uttrs_counts = command_df.spk.value_counts()
sv_spks = list(uttrs_counts[:10].index)  # top 10 speakers whose number of recored uttrs is high
si_df = command_df[(~command_df.spk.isin(sv_spks))&(command_df.sent.isin(pick_words))]
si_spks = list(si_df.spk.unique())
sv_df = command_df[(command_df.spk.isin(sv_spks))&(command_df.sent.isin(pick_words))]
unknown_si_df = command_df[(command_df.spk.isin(si_spks)) & (~command_df.sent.isin(pick_words))]

# %%
import random 

si_train = dict()
si_val = dict()
si_test = dict()

for word in pick_words:
    word_df = si_df[si_df.sent == word]
    si_train[word] = word_df.sample(frac=0.8)
    si_val[word] = word_df.drop(index=si_train[word].index)
    si_test[word] = si_val[word]

# %%
import csv
import random

tags = ['train', 'val', 'test']
# choose a si split
sets = {'train':si_train, 'val':si_val, 'test':si_test}
manifest_dir = "manifests/commands/word"
if not os.path.exists(manifest_dir):
    os.makedirs(manifest_dir)
    
for word in pick_words:
    for tag in tags:
        samples = []
        save_path = os.path.join(manifest_dir,'si_{}_{}_manifest.csv'.format(word, tag))
        with open(save_path, 'w') as f:
            for index, row in sets[tag][word].iterrows():
                file_path = os.path.join(data_dir, row.sent, row.file)
                label = row.label
                sample = ','.join([file_path, str(label)])
                samples.append(sample)
#             unknown_samples = unknown_si_df.sample(n=len(sample))
#             for index, row in unknown_samples.iterrows():
#                 file_path = os.path.join(data_dir, row.sent, row.file)
#                 label = 0
#                 sample = ','.join([file_path, str(label)])
#                 samples.append(sample)
            random.shuffle(samples)
            writer = csv.writer(f, delimiter='\n', quoting=csv.QUOTE_NONE)
            writer.writerow(samples)
            print("{} was written".format(save_path))
# Out:
# manifests/commands/word/si_yes_train_manifest.csv was written
# manifests/commands/word/si_yes_val_manifest.csv was written
# manifests/commands/word/si_yes_test_manifest.csv was written
# manifests/commands/word/si_no_train_manifest.csv was written
# manifests/commands/word/si_no_val_manifest.csv was written
# manifests/commands/word/si_no_test_manifest.csv was written
# manifests/commands/word/si_up_train_manifest.csv was written
# manifests/commands/word/si_up_val_manifest.csv was written
# manifests/commands/word/si_up_test_manifest.csv was written
# manifests/commands/word/si_down_train_manifest.csv was written
# manifests/commands/word/si_down_val_manifest.csv was written
# manifests/commands/word/si_down_test_manifest.csv was written

# %%
model = "cnn-trad-pool2"
dataset = "command"

global_config = dict(model=model, dataset=dataset,
                     no_cuda=False,  gpu_no=0, 
                     dev_every=1, seed=0, use_nesterov=False,
                     cache_size=32768, momentum=0.9, weight_decay=0.00001, 
                     num_workers=16, print_step=200,
                )

# %%
builder = hk.ConfigBuilder(
                mod.find_config(model),
                mod.SpeechDataset.default_config(dataset),
                global_config)
parser = builder.build_argparse()
si_config = builder.config_from_argparse(parser)
si_config['model_class'] = mod.find_model(model)
si_config['n_feature_maps1'] = 64
hk.set_seed(si_config)

# %%
si_config['n_labels'] = 2000
si_config['batch_size'] = 32
si_config['n_epochs'] = 30
si_config['lr'] = [0.001, 0.0001]
si_config['schedule'] = [1000]
si_config['bn_size'] = 256

# %%
manifest_dir = "./manifests/commands/word/"
for word in pick_words:
    print("########### training {} word ##########".format(word))
    for tag in ['train', 'val', 'test']:
        si_config['{}_manifest'.format(tag)]=os.path.join(manifest_dir,'si_{}_{}_manifest.csv'.format(word, tag))
    si_model = load_pretrained_model("models/si_command_sent_model.pt")
    si_config['output_file'] = "models/si_{}_model.pt".format(word)
    hk.train(si_config, model=si_model)
# Out:
# ########### training yes word ##########
# epoch #0, final dev accuracy: 0.07351190476190476
# saving best model...
# epoch #1, final dev accuracy: 0.22142857142857145
# saving best model...
# epoch #2, final dev accuracy: 0.3273809523809524
# saving best model...
# train step #199 accuracy: 0.96875, loss: 0.2874186336994171
# epoch #3, final dev accuracy: 0.39017857142857143
# saving best model...
# epoch #4, final dev accuracy: 0.40208333333333335
# saving best model...
# epoch #5, final dev accuracy: 0.4330357142857143
# saving best model...
# train step #399 accuracy: 0.96875, loss: 0.09429645538330078
# epoch #6, final dev accuracy: 0.40773809523809523
# epoch #7, final dev accuracy: 0.4238095238095238
# epoch #8, final dev accuracy: 0.42291666666666666
# epoch #9, final dev accuracy: 0.42886904761904765
# train step #599 accuracy: 1.0, loss: 0.004308730363845825
# epoch #10, final dev accuracy: 0.4270833333333333
# epoch #11, final dev accuracy: 0.44523809523809527
# saving best model...
# epoch #12, final dev accuracy: 0.4336309523809524
# epoch #13, final dev accuracy: 0.4726190476190476
# saving best model...
# train step #799 accuracy: 1.0, loss: 0.009228736162185669
# epoch #14, final dev accuracy: 0.47291666666666665
# saving best model...
# epoch #15, final dev accuracy: 0.47440476190476194
# saving best model...
# epoch #16, final dev accuracy: 0.46309523809523806
# train step #999 accuracy: 1.0, loss: 0.0028151273727416992
# changing learning rate to 0.0001
# epoch #17, final dev accuracy: 0.47559523809523807
# saving best model...
# epoch #18, final dev accuracy: 0.47708333333333336
# saving best model...
# epoch #19, final dev accuracy: 0.48125
# saving best model...
# epoch #20, final dev accuracy: 0.48125
# train step #1199 accuracy: 1.0, loss: 0.0028527379035949707
# epoch #21, final dev accuracy: 0.48125
# epoch #22, final dev accuracy: 0.4866071428571429
# saving best model...
# epoch #23, final dev accuracy: 0.4785714285714286
# train step #1399 accuracy: 1.0, loss: 0.001948714256286621
# epoch #24, final dev accuracy: 0.47440476190476194
# epoch #25, final dev accuracy: 0.4785714285714286
# epoch #26, final dev accuracy: 0.4663690476190476
# epoch #27, final dev accuracy: 0.475
# train step #1599 accuracy: 1.0, loss: 0.0021112561225891113
# epoch #28, final dev accuracy: 0.48392857142857143
# epoch #29, final dev accuracy: 0.48125
# final test accuracy: 0.4805194805194805
# ########### training no word ##########
# epoch #0, final dev accuracy: 0.08303571428571428
# saving best model...
# epoch #1, final dev accuracy: 0.19375
# saving best model...
# epoch #2, final dev accuracy: 0.29345238095238096
# saving best model...
# train step #199 accuracy: 0.84375, loss: 0.738933801651001
# epoch #3, final dev accuracy: 0.34345238095238095
# saving best model...
# epoch #4, final dev accuracy: 0.37916666666666665
# saving best model...
# epoch #5, final dev accuracy: 0.38630952380952377
# saving best model...
# train step #399 accuracy: 0.96875, loss: 0.07846421003341675
# epoch #6, final dev accuracy: 0.41190476190476194
# saving best model...
# epoch #7, final dev accuracy: 0.40714285714285714
# epoch #8, final dev accuracy: 0.41309523809523807
# saving best model...
# epoch #9, final dev accuracy: 0.41755952380952377
# saving best model...
# train step #599 accuracy: 1.0, loss: 0.007706105709075928
# epoch #10, final dev accuracy: 0.42232142857142857
# saving best model...
# epoch #11, final dev accuracy: 0.44434523809523807
# saving best model...
# epoch #12, final dev accuracy: 0.42083333333333334
# epoch #13, final dev accuracy: 0.42023809523809524
# train step #799 accuracy: 1.0, loss: 0.003902941942214966
# epoch #14, final dev accuracy: 0.4276785714285714
# epoch #15, final dev accuracy: 0.4285714285714286
# epoch #16, final dev accuracy: 0.4244047619047619
# train step #999 accuracy: 1.0, loss: 0.0028991103172302246
# changing learning rate to 0.0001
# epoch #17, final dev accuracy: 0.42291666666666666
# epoch #18, final dev accuracy: 0.42976190476190473
# epoch #19, final dev accuracy: 0.4300595238095238
# epoch #20, final dev accuracy: 0.43273809523809526
# train step #1199 accuracy: 1.0, loss: 0.0012694597244262695
# epoch #21, final dev accuracy: 0.431547619047619
# epoch #22, final dev accuracy: 0.431547619047619
# epoch #23, final dev accuracy: 0.42886904761904765
# train step #1399 accuracy: 1.0, loss: 0.002228379249572754
# epoch #24, final dev accuracy: 0.44702380952380955
# saving best model...
# epoch #25, final dev accuracy: 0.43898809523809523
# epoch #26, final dev accuracy: 0.4395833333333333
# epoch #27, final dev accuracy: 0.4369047619047619
# train step #1599 accuracy: 1.0, loss: 0.005186200141906738
# epoch #28, final dev accuracy: 0.44434523809523807
# epoch #29, final dev accuracy: 0.44047619047619047
# final test accuracy: 0.44372294372294374
# ########### training up word ##########
# epoch #0, final dev accuracy: 0.07142857142857142
# saving best model...
# epoch #1, final dev accuracy: 0.17202380952380952
# saving best model...
# epoch #2, final dev accuracy: 0.2961309523809524
# saving best model...
# train step #199 accuracy: 0.90625, loss: 0.6180932521820068
# epoch #3, final dev accuracy: 0.3142857142857143
# saving best model...
# epoch #4, final dev accuracy: 0.35654761904761906
# saving best model...
# epoch #5, final dev accuracy: 0.39166666666666666
# saving best model...
# train step #399 accuracy: 0.96875, loss: 0.06053796410560608
# epoch #6, final dev accuracy: 0.3943452380952381
# saving best model...
# epoch #7, final dev accuracy: 0.3931547619047619
# epoch #8, final dev accuracy: 0.4133928571428571
# saving best model...
# epoch #9, final dev accuracy: 0.4044642857142857
# train step #599 accuracy: 1.0, loss: 0.014411389827728271
# epoch #10, final dev accuracy: 0.4133928571428571
# epoch #11, final dev accuracy: 0.4133928571428571
# epoch #12, final dev accuracy: 0.4133928571428571
# epoch #13, final dev accuracy: 0.4220238095238095
# saving best model...
# train step #799 accuracy: 1.0, loss: 0.01511770486831665
# epoch #14, final dev accuracy: 0.3973214285714286
# epoch #15, final dev accuracy: 0.41875
# epoch #16, final dev accuracy: 0.41875
# train step #999 accuracy: 1.0, loss: 0.0045653581619262695
# changing learning rate to 0.0001
# epoch #17, final dev accuracy: 0.4303571428571429
# saving best model...
# epoch #18, final dev accuracy: 0.42351190476190476
# epoch #19, final dev accuracy: 0.4181547619047619
# epoch #20, final dev accuracy: 0.43184523809523806
# saving best model...
# train step #1199 accuracy: 1.0, loss: 0.004466235637664795
# epoch #21, final dev accuracy: 0.42589285714285713
# epoch #22, final dev accuracy: 0.4232142857142857
# epoch #23, final dev accuracy: 0.43333333333333335
# saving best model...
# train step #1399 accuracy: 1.0, loss: 0.0028560757637023926
# epoch #24, final dev accuracy: 0.4285714285714286
# epoch #25, final dev accuracy: 0.4232142857142857
# epoch #26, final dev accuracy: 0.4413690476190476
# saving best model...
# epoch #27, final dev accuracy: 0.43660714285714286
# train step #1599 accuracy: 1.0, loss: 0.004785031080245972
# epoch #28, final dev accuracy: 0.4354166666666667
# epoch #29, final dev accuracy: 0.4428571428571429
# saving best model...
# final test accuracy: 0.43506493506493504
# ########### training down word ##########
# epoch #0, final dev accuracy: 0.06666666666666667
# saving best model...
# epoch #1, final dev accuracy: 0.23068181818181815
# saving best model...
# epoch #2, final dev accuracy: 0.32196969696969696
# saving best model...
# train step #199 accuracy: 0.8125, loss: 0.7017890810966492
# epoch #3, final dev accuracy: 0.3867424242424242
# saving best model...
# epoch #4, final dev accuracy: 0.4011363636363636
# saving best model...
# epoch #5, final dev accuracy: 0.42007575757575755
# saving best model...
# train step #399 accuracy: 1.0, loss: 0.08161598443984985
# epoch #6, final dev accuracy: 0.4257575757575758
# saving best model...
# epoch #7, final dev accuracy: 0.43446969696969695
# saving best model...
# epoch #8, final dev accuracy: 0.4426136363636363
# saving best model...
# epoch #9, final dev accuracy: 0.43446969696969695
# train step #599 accuracy: 0.96875, loss: 0.1831880807876587
# epoch #10, final dev accuracy: 0.440530303030303
# epoch #11, final dev accuracy: 0.4263257575757576
# epoch #12, final dev accuracy: 0.4202651515151515
# epoch #13, final dev accuracy: 0.4365530303030303
# train step #799 accuracy: 1.0, loss: 0.002944767475128174
# epoch #14, final dev accuracy: 0.43257575757575756
# epoch #15, final dev accuracy: 0.44090909090909086
# epoch #16, final dev accuracy: 0.4287878787878788
# train step #999 accuracy: 1.0, loss: 0.0021150708198547363
# changing learning rate to 0.0001
# epoch #17, final dev accuracy: 0.43503787878787875
# epoch #18, final dev accuracy: 0.45492424242424245
# saving best model...
# epoch #19, final dev accuracy: 0.45511363636363633
# saving best model...
# epoch #20, final dev accuracy: 0.45530303030303027
# saving best model...
# train step #1199 accuracy: 1.0, loss: 0.0019606947898864746
# epoch #21, final dev accuracy: 0.45530303030303027
# epoch #22, final dev accuracy: 0.46325757575757576
# saving best model...
# epoch #23, final dev accuracy: 0.44943181818181815
# train step #1399 accuracy: 1.0, loss: 0.0023224949836730957
# epoch #24, final dev accuracy: 0.4634469696969697
# saving best model...
# epoch #25, final dev accuracy: 0.4575757575757576
# epoch #26, final dev accuracy: 0.4535984848484848
# epoch #27, final dev accuracy: 0.4575757575757576
# train step #1599 accuracy: 1.0, loss: 0.00543522834777832
# epoch #28, final dev accuracy: 0.4556818181818182
# epoch #29, final dev accuracy: 0.4596590909090909
# final test accuracy: 0.46405228758169936

# %%
# load models
models = dict.fromkeys(pick_words+["command_random", 'command_sent'])
for key in models.keys():
    model = si_config['model_class'](si_config)
    model.load("models/si_{}_model.pt".format(key))
    models[key] = model

# %% [markdown]
# ***
# ### Check the quality of models

# %%
# cross check
si_model = models['yes']
si_config['test_manifest'] = "manifests/commands/word/si_down_test_manifest.csv"
hk.evaluate(si_config,si_model)
# Out:
# final test accuracy: 0.16339869281045752

# %%
from scipy.spatial.distance import cosine
import random
import itertools

for dirpath, dir, files in os.walk("/home/muncok/DL/dataset/SV_sets/speech_commands/down"):
    neg_pairs = list(itertools.combinations(files, 2))
    neg_pairs = random.choices(pos_pairs, k=1000)

# %%
from collections import defaultdict
scores = defaultdict(list)

# %%
best_model = dict.fromkeys(models.keys(), 0)
for a, b in neg_pairs:
    if a.split('_')[0] == b.split('_')[0]:
        # positive pair
        continue
    best_score = 1
    for model in models.keys():
        si_model = models[model]
        path1 = os.path.join(dirpath, a)
        path2 = os.path.join(dirpath, b)
        embed1 = hk.embed(si_config, si_model, path1)
        embed2 = hk.embed(si_config, si_model, path2)
        score = 1 - cosine(embed1, embed2)
        scores[model].append(score)
        if score < best_score:
            best_word = model
            best_score = score
    best_model[best_word] += 1
print(best_model)
# Out:
# {'yes': 69, 'no': 177, 'up': 113, 'down': 215, 'command_random': 273, 'command_sent': 153}

# %%
subplot(131)
plt.xlim([-0.2, 1.0])
plt.title("yes")
plt.hist(scores['yes'], color='y')
subplot(132)
plt.xlim([-0.2, 1.0])
plt.title("down")
plt.hist(scores['down'])
subplot(133)
plt.xlim([-0.2, 1.0])
plt.title("universal")
plt.hist(scores['command_random'], color='r')
# Out:
# (array([  14.,   91.,   81.,  216.,  147.,  145.,  107.,  132.,   42.,   25.]),
#  array([-0.23970045, -0.17528329, -0.11086614, -0.04644898,  0.01796818,
#          0.08238534,  0.1468025 ,  0.21121965,  0.27563681,  0.34005397,
#          0.40447113]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ***
# ## Verification Learning

# %%
sv_spks = list(sv_df.spk.unique())
random.shuffle(sv_spks)
enroll_spks = sv_spks[:3]
test_spks = sv_spks[3:]
# sv_df was too small, so includes utterances not using pick_word
sv_df = command_df[(command_df.spk.isin(sv_spks))]

# %%
import random 

sv_train = dict()
sv_val = dict()
sv_test = dict()

# labelded to 1
# it should not include dev_uttrs (saved to evaluate)
for spk in enroll_spks:
    spk_df = sv_df[sv_df.spk == spk]
    sv_train[spk] = spk_df.sample(frac=0.8)
    sv_val[spk] = spk_df.drop(index=sv_train[spk].index)
    sv_test[spk] = sv_val[spk]

# labelded to 0
sv_unknown_df = command_df[(command_df.spk.isin(test_spks))]
unknown_train = sv_unknown_df.sample(frac=0.8)
unknown_val = sv_unknown_df.drop(index=unknown_train.index)
unknown_test = unknown_val

# %% [markdown]
# ### enrollment

# %%
enroll_uttrs = pd.DataFrame()
dev_uttrs = pd.DataFrame()
enroll_pts = 0.8

for spk in enroll_spks:
    enls = sv_train[spk].sample(n=20)
    enroll_uttrs = pd.concat([enls, enroll_uttrs])
# splits enroll and dev
# for spk in enroll_spks:
#     spk_df = sv_df[sv_df.spk == spk]
#     assert(len(spk_df) != 0)
#     for sent in pick_words:
#         sent_uttrs = spk_df[spk_df.sent == sent]
#         if len(sent_uttrs) < 2:
#             enls = sent_uttrs.sample(n=1)
#         else:
#             enls = sent_uttrs.sample(frac=enroll_pts)
#         devs = sent_uttrs.drop(index=enls.index)
#         enroll_uttrs = pd.concat([enls, enroll_uttrs])
#         dev_uttrs = pd.concat([devs, dev_uttrs])

# %%
print("enrolled speakers: {}".format(enroll_spks))
print("number of enroll uttrs per spk: %d"%(len(enroll_uttrs)/len(enroll_spks)))
# Out:
# enrolled speakers: ['b9f46737', 'c1d39ce8', '28ce0c58']
# number of enroll uttrs per spk: 20

# %%
sents = list(enroll_uttrs.sent.unique())
# sents = pick_words

# %%
import csv
import random

# delete existing files
for file in os.listdir(manifest_dir):
    file_path = os.path.join(manifest_dir, file)
    if os.path.isfile(file_path):
        os.unlink(file_path)
        
manifest_dir = "./manifests/commands/enroll/"
for spk in enroll_spks:
    samples = []
    save_path = os.path.join(manifest_dir,'enroll_{}_{}_manifest.csv'.format("command", spk))
    with open(save_path, 'w') as f:
        for index, row in enroll_uttrs[enroll_uttrs.spk == spk].iterrows():
            file_path = os.path.join(data_dir, row.sent, row.file)
            sent_label = sents.index(row.sent)
            sample = ','.join([file_path, str(sent_label)])
            samples.append(sample)
        writer = csv.writer(f, delimiter='\n', quoting=csv.QUOTE_NONE)
        writer.writerow(samples)
        print("{} was written".format(save_path))
# Out:
# ./manifests/commands/enroll/enroll_command_b9f46737_manifest.csv was written
# ./manifests/commands/enroll/enroll_command_c1d39ce8_manifest.csv was written
# ./manifests/commands/enroll/enroll_command_28ce0c58_manifest.csv was written

# %%
# enrolling speakers
# generating speaker models

manifest_dir =  "./manifests/commands/enroll/"
word_spk_models = dict()
uni_spk_models = dict()
for spk in enroll_spks:
    manifest_path = os.path.join(manifest_dir, 'enroll_{}_{}_manifest.csv'.format("command", spk))
    si_config['test_manifest'] =  manifest_path
    word_spk_models[spk] = hk.enroll(si_config, nb_sent=len(sents), model=models['command_sent'])
    uni_spk_models[spk] = np.mean(word_spk_models[spk], axis=0)

# %% [markdown]
# # verification

# %%
sv_df.spk.value_counts()
# Out:
# c1d39ce8    205
# c120e80e    174
# cb8f8307    160
# cb2929ce    150
# 28ce0c58    127
# e7ea8b76    124
# 7c1d8533    119
# d0faf7e4    117
# bdee441c    116
# b9f46737    114
# Name: spk, dtype: int64

# %%
import csv
import random

tags = ['train', 'val', 'test']
# choose a sv split
sets = {'train':sv_train, 'val':sv_val, 'test':sv_test}
unknown_sets = {'train':unknown_train, 'val':unknown_val, 'test':unknown_test}
manifest_dir = "manifests/commands/word"
if not os.path.exists(manifest_dir):
    os.makedirs(manifest_dir)

universal_samples = {'train':[], 'val':[], 'test':[]}
for spk in enroll_spks:
    for tag in tags:
        samples = []
        save_path = os.path.join(manifest_dir,'sv_{}_{}_manifest.csv'.format(spk, tag))
        with open(save_path, 'w') as f:
            # TC & TW - Target Correct, Target Wrong
            for index, row in sets[tag][spk].iterrows():
                file_path = os.path.join(data_dir, row.sent, row.file)
                label = 1
                sample = ','.join([file_path, str(label)])
                samples.append(sample)
            # IC & IW = Imposter Correct & Imposter Wrong
#             unknown_samples = unknown_sets[tag].sample(n=len(samples))
            unknown_samples = unknown_sets[tag]
            for index, row in unknown_samples.iterrows():
                file_path = os.path.join(data_dir, row.sent, row.file)
                label = 0
                sample = ','.join([file_path, str(label)])
                samples.append(sample)
            random.shuffle(samples)
            writer = csv.writer(f, delimiter='\n', quoting=csv.QUOTE_NONE)
            writer.writerow(samples)
            universal_samples[tag] += samples
            print("{} was written".format(save_path))
# Out:
# manifests/commands/word/sv_b9f46737_train_manifest.csv was written
# manifests/commands/word/sv_b9f46737_val_manifest.csv was written
# manifests/commands/word/sv_b9f46737_test_manifest.csv was written
# manifests/commands/word/sv_c1d39ce8_train_manifest.csv was written
# manifests/commands/word/sv_c1d39ce8_val_manifest.csv was written
# manifests/commands/word/sv_c1d39ce8_test_manifest.csv was written
# manifests/commands/word/sv_28ce0c58_train_manifest.csv was written
# manifests/commands/word/sv_28ce0c58_val_manifest.csv was written
# manifests/commands/word/sv_28ce0c58_test_manifest.csv was written

# %%
model = "cnn-trad-pool2"
dataset = "command"

global_config = dict(model=model, dataset=dataset,
                     no_cuda=False,  gpu_no=0, 
                     dev_every=10, seed=0, use_nesterov=False,
                     cache_size=32768, momentum=0.9, weight_decay=0.00001, 
                     num_workers=16, print_step=1000,
                )

# %%
builder = hk.ConfigBuilder(
                mod.find_config(model),
                mod.SpeechDataset.default_config(dataset),
                global_config)
parser = builder.build_argparse()
sv_config = builder.config_from_argparse(parser)

hk.set_seed(sv_config)

# %%
sv_config['model_class'] = mod.logRegModel
sv_config['n_feature_maps1'] = 64
sv_config['n_labels'] = 2000
sv_config['batch_size'] = 16
sv_config['n_epochs'] = 10
sv_config['lr'] = [0.1]
sv_config['schedule'] = [np.inf]
sv_config['bn_size'] = 256

# %%
import itertools
import torch

def load_model(config, pretrained_path):
    pre_state = torch.load(pretrained_path)
    pre_trained_state = {k: v for k, v in pre_state.items()}

    model = config['model_class'](config)
    new_state = model.state_dict()
    new_state.update(pre_trained_state)
    model.load_state_dict(new_state)      
    for param in model.parameters():
        param.requires_grad = True
        
    for param in model.linear.parameters():
        param.requires_grad = True

#     for param in model.output.parameters():
#         param.requires_grad = True
        
    return model

# %% [markdown]
# ### classifier using universal feature

# %%
sv_models = dict.fromkeys(enroll_spks)
for spk in enroll_spks:
    sv_models[spk] = load_model(sv_config, "models/si_{}_model.pt".format('command_random'))
    print(id(sv_models[spk]))
# Out:
# 139740097508184
# 139740056056104
# 139740050756384

# %%
for spk in enroll_spks:
    for tag in ['train', 'val', 'test']:
        sv_config['{}_manifest'.format(tag)]=os.path.join(manifest_dir,'sv_{}_{}_manifest.csv'.format(spk, tag))
    # universal feature extractor = "si_command_random_model.pt"
    print("training {}'s classifier".format(spk))
    sv_config['output_file'] = "models/sv_uni_model.pt".format(spk)
    print('-'*20)
# Out:
# epoch #9, final dev accuracy: 0.9444444444444444
# saving best model...
# train step #999 accuracy: 1.0, loss: 0.0078896414488554
# epoch #19, final dev accuracy: 0.9556327160493827
# saving best model...
# final test accuracy: 0.9583333333333334
# --------------------
# Process Process-19380:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
# Process Process-19385:
# Process Process-19382:
# Process Process-19390:
# Process Process-19392:
# Process Process-19388:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-407-90b089dbb6ef> in <module>()
#       5     # universal feature extractor = "si_command_random_model.pt"
#       6     sv_config['output_file'] = "models/sv_uni_model.pt".format(spk)
# ----> 7     hk.sv_train(sv_config, spk_model=uni_spk_models[spk], model=sv_uni_model)
#       8     print('-'*20)
#
# ~/DL/projects/sv_system/honk_sv/train.py in sv_train(config, spk_model, model)
#     511                 model_in.transpose_(0,1)
#     512             if not config["no_cuda"]:
# --> 513                 model_in = model_in.cuda()
#     514                 labels = labels.unsqueeze(1).float().cuda()
#     515             model_in = Variable(model_in, requires_grad=False)
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/_utils.py in _cuda(self, device, async)
#      64         else:
#      65             new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 66             return new_type(self.size()).copy_(self, async)
#      67
#      68
#
# KeyboardInterrupt:
# Process Process-19383:
# Process Process-19387:
# Process Process-19381:
# Traceback (most recent call last):
# Process Process-19379:
# Process Process-19384:
# Process Process-19386:
# Traceback (most recent call last):
# Process Process-19389:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     res = self._reader.recv_bytes()
# KeyboardInterrupt
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
# KeyboardInterrupt
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
# KeyboardInterrupt
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Process Process-19377:
# Process Process-19378:
# Traceback (most recent call last):
# Process Process-19391:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt

# %%
sv_uni_model = load_model(sv_config, "models/si_{}_model.pt".format('command_random'))

# %%
for spk in enroll_spks:
    for tag in ['train', 'val', 'test']:
        sv_config['{}_manifest'.format(tag)]=os.path.join(manifest_dir,'sv_{}_{}_manifest.csv'.format(spk, tag))
    # universal feature extractor = "si_command_random_model.pt"
    print("training {}'s classifier".format(spk))
    sv_config['output_file'] = "models/sv_uni_model.pt".format(spk)
    hk.sv_train(sv_config, spk_model=uni_spk_models[spk], model=sv_models[spk])
    print('-'*20)
# Out:
# epoch #9, final dev accuracy: 0.9444444444444444
# saving best model...
# train step #999 accuracy: 1.0, loss: 0.0078896414488554
# epoch #19, final dev accuracy: 0.9556327160493827
# saving best model...
# final test accuracy: 0.9583333333333334
# --------------------
# Process Process-19380:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
# Process Process-19385:
# Process Process-19382:
# Process Process-19390:
# Process Process-19392:
# Process Process-19388:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-407-90b089dbb6ef> in <module>()
#       5     # universal feature extractor = "si_command_random_model.pt"
#       6     sv_config['output_file'] = "models/sv_uni_model.pt".format(spk)
# ----> 7     hk.sv_train(sv_config, spk_model=uni_spk_models[spk], model=sv_uni_model)
#       8     print('-'*20)
#
# ~/DL/projects/sv_system/honk_sv/train.py in sv_train(config, spk_model, model)
#     511                 model_in.transpose_(0,1)
#     512             if not config["no_cuda"]:
# --> 513                 model_in = model_in.cuda()
#     514                 labels = labels.unsqueeze(1).float().cuda()
#     515             model_in = Variable(model_in, requires_grad=False)
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/_utils.py in _cuda(self, device, async)
#      64         else:
#      65             new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 66             return new_type(self.size()).copy_(self, async)
#      67
#      68
#
# KeyboardInterrupt:
# Process Process-19383:
# Process Process-19387:
# Process Process-19381:
# Traceback (most recent call last):
# Process Process-19379:
# Process Process-19384:
# Process Process-19386:
# Traceback (most recent call last):
# Process Process-19389:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     res = self._reader.recv_bytes()
# KeyboardInterrupt
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
# KeyboardInterrupt
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
# KeyboardInterrupt
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Process Process-19377:
# Process Process-19378:
# Traceback (most recent call last):
# Process Process-19391:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt

# %%
sv_config['n_epochs'] = 0
for spk in enroll_spks:
    for tag in ['train', 'val', 'test']:
        sv_config['{}_manifest'.format(tag)]=os.path.join(manifest_dir,'sv_{}_{}_manifest.csv'.format(spk, tag))
    # universal feature extractor = "si_command_random_model.pt"
    print("training {}'s classifier".format(spk))
    sv_config['output_file'] = "models/sv_{}_model.pt".format(spk)
    hk.sv_train(sv_config, spk_model=uni_spk_models[spk], model=sv_models[spk])
    print('-'*20)
# Out:
# training b9f46737's classifier
# final test accuracy: 0.9598214285714286
# --------------------
# training c1d39ce8's classifier
# final test accuracy: 1.0
# --------------------
# training 28ce0c58's classifier
# final test accuracy: 0.962797619047619
# --------------------

# %%
sv_config['n_epochs'] = 0 
for tag in ['train', 'val', 'test']:
    sv_config['{}_manifest'.format(tag)]=os.path.join(manifest_dir,'sv_{}_{}_manifest.csv'.format('b9f46737', tag))
hk.sv_train(sv_config, spk_model=uni_spk_models['b9f46737'], model=sv_models['c1d39ce8'])
# Out:
# final test accuracy: 0.8915816326530612

# %%
import voxc_sv as vox
from voxc_sv.utils import spk_verify, roc_auc_eer
uni_pos_scores = []
uni_neg_scores = []
speaker_model = uni_spk_models

pos_utters = pd.concat([v for v in sv_test.values()])
neg_utters = unknown_test

for i, row in pos_utters.iterrows():
    audio_path = os.path.join(data_dir, row.sent, row.file)
    test_in = hk.embed(sv_config, sv_uni_model, audio_path)
    score = spk_verify(uni_spk_models, test_in, None)
#     score = sv_models[row.spk](test_in, uni_spk_models[row.spk])
    uni_pos_scores.append(score)
    
for i, row in neg_utters.iterrows():
    audio_path = os.path.join(data_dir, row.sent, row.file)
    test_in = hk.embed(sv_config, sv_uni_model, audio_path)
    score = spk_verify(uni_spk_models, test_in)
    uni_neg_scores.append(score)

dists = np.concatenate((uni_pos_scores, uni_neg_scores), 0)
labels = np.concatenate((np.ones_like(uni_pos_scores), np.zeros_like(uni_neg_scores)), 0)
auc_, eer_, uni_eer_ths = roc_auc_eer(dists, labels)
print("auc: {}, eer: {}".format(auc_, eer_))
uni_pos_scores = np.array(uni_pos_scores)
uni_neg_scores = np.array(uni_neg_scores)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-397-a9448e644fee> in <module>()
#      10 for i, row in pos_utters.iterrows():
#      11     audio_path = os.path.join(data_dir, row.sent, row.file)
# ---> 12     test_in = hk.embed(sv_config, sv_uni_model, audio_path)
#      13     score = spk_verify(uni_spk_models, test_in, None)
#      14 #     score = sv_models[row.spk](test_in, uni_spk_models[row.spk])
#
# ~/DL/projects/sv_system/honk_sv/train.py in embed(config, model, audio)
#      87     if not config["no_cuda"]:
#      88         data_in = data_in.cuda()
# ---> 89     feature = model(data_in, feature=True).cpu().data.numpy()
#      90     return feature
#      91
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# ~/DL/projects/sv_system/honk_sv/model.py in forward(self, x, spk_model, feature)
#     359     def forward(self, x, spk_model=None, feature=False):
#     360         x = super().forward(x, feature=True)
# --> 361         spk_model = spk_model.expand(x.size(0), x.size(1))
#     362         x = F.cosine_similarity(x, spk_model)
#     363         x = x.unsqueeze(1)
#
# AttributeError: 'NoneType' object has no attribute 'expand'

# %%
len(neg_utters)
# Out:
# 192

# %%
subplot(121)
plt.xlim([-0.2, 1.0])
plt.title("uni, positive")
plt.hist(uni_pos_scores)
subplot(122)
plt.xlim([-0.2, 1.0])
plt.title("uni, negative")
plt.hist(uni_neg_scores, color='r')
# Out:
# (array([  4.,   7.,  33.,  46.,  30.,  34.,  21.,   9.,   6.,   2.]),
#  array([-0.07925441, -0.02346193,  0.03233055,  0.08812302,  0.1439155 ,
#          0.19970797,  0.25550045,  0.31129293,  0.3670854 ,  0.42287788,
#          0.47867035]),
#  <a list of 10 Patch objects>)

# %%
pos_utters[uni_pos_scores <0.2]
# Out:
#                       spk    sent                   file    set  label
# rightb9f467371   b9f46737   right  b9f46737_nohash_1.wav  train   1419
# sheilab9f467370  b9f46737  sheila  b9f46737_nohash_0.wav  train   1419
# upb9f467370      b9f46737      up  b9f46737_nohash_0.wav  train   1419
# upb9f467374      b9f46737      up  b9f46737_nohash_4.wav  train   1419
# sixb9f467370     b9f46737     six  b9f46737_nohash_0.wav  train   1419
# sixb9f467373     b9f46737     six  b9f46737_nohash_3.wav  train   1419
# sevenb9f467372   b9f46737   seven  b9f46737_nohash_2.wav  train   1419
# eightb9f467373   b9f46737   eight  b9f46737_nohash_3.wav  train   1419
# oneb9f467371     b9f46737     one  b9f46737_nohash_1.wav  train   1419
# stopb9f467372    b9f46737    stop  b9f46737_nohash_2.wav  train   1419
# yesb9f467372     b9f46737     yes  b9f46737_nohash_2.wav  train   1419
# threeb9f467374   b9f46737   three  b9f46737_nohash_4.wav  train   1419
# offb9f467372     b9f46737     off  b9f46737_nohash_2.wav  train   1419
# offb9f467373     b9f46737     off  b9f46737_nohash_3.wav  train   1419
# nob9f467374      b9f46737      no  b9f46737_nohash_4.wav  train   1419
# nob9f467373      b9f46737      no  b9f46737_nohash_3.wav  train   1419
# fourb9f467370    b9f46737    four  b9f46737_nohash_0.wav  train   1419
# fourb9f467374    b9f46737    four  b9f46737_nohash_4.wav  train   1419
# gob9f467373      b9f46737      go  b9f46737_nohash_3.wav  train   1419
# nineb9f467375    b9f46737    nine  b9f46737_nohash_5.wav  train   1419
# zeroc1d39ce88    c1d39ce8    zero  c1d39ce8_nohash_8.wav  train    102
# zeroc1d39ce86    c1d39ce8    zero  c1d39ce8_nohash_6.wav  train    102
# zeroc1d39ce83    c1d39ce8    zero  c1d39ce8_nohash_3.wav  train    102
# sheilac1d39ce81  c1d39ce8  sheila  c1d39ce8_nohash_1.wav  train    102
# upc1d39ce84      c1d39ce8      up  c1d39ce8_nohash_4.wav  train    102
# leftc1d39ce85    c1d39ce8    left  c1d39ce8_nohash_5.wav  train    102
# leftc1d39ce84    c1d39ce8    left  c1d39ce8_nohash_4.wav  train    102
# fivec1d39ce80    c1d39ce8    five  c1d39ce8_nohash_0.wav  train    102
# fivec1d39ce83    c1d39ce8    five  c1d39ce8_nohash_3.wav  train    102
# sevenc1d39ce87   c1d39ce8   seven  c1d39ce8_nohash_7.wav  train    102
# ...                   ...     ...                    ...    ...    ...
# onec1d39ce83     c1d39ce8     one  c1d39ce8_nohash_3.wav  train    102
# stopc1d39ce86    c1d39ce8    stop  c1d39ce8_nohash_6.wav  train    102
# stopc1d39ce80    c1d39ce8    stop  c1d39ce8_nohash_0.wav  train    102
# stopc1d39ce87    c1d39ce8    stop  c1d39ce8_nohash_7.wav  train    102
# yesc1d39ce84     c1d39ce8     yes  c1d39ce8_nohash_4.wav  train    102
# yesc1d39ce81     c1d39ce8     yes  c1d39ce8_nohash_1.wav  train    102
# downc1d39ce85    c1d39ce8    down  c1d39ce8_nohash_5.wav  train    102
# threec1d39ce88   c1d39ce8   three  c1d39ce8_nohash_8.wav  train    102
# threec1d39ce85   c1d39ce8   three  c1d39ce8_nohash_5.wav  train    102
# threec1d39ce80   c1d39ce8   three  c1d39ce8_nohash_0.wav  train    102
# threec1d39ce87   c1d39ce8   three  c1d39ce8_nohash_7.wav  train    102
# offc1d39ce86     c1d39ce8     off  c1d39ce8_nohash_6.wav  train    102
# offc1d39ce87     c1d39ce8     off  c1d39ce8_nohash_7.wav  train    102
# noc1d39ce80      c1d39ce8      no  c1d39ce8_nohash_0.wav  train    102
# noc1d39ce84      c1d39ce8      no  c1d39ce8_nohash_4.wav  train    102
# fourc1d39ce89    c1d39ce8    four  c1d39ce8_nohash_9.wav  train    102
# onc1d39ce85      c1d39ce8      on  c1d39ce8_nohash_5.wav  train    102
# onc1d39ce82      c1d39ce8      on  c1d39ce8_nohash_2.wav  train    102
# goc1d39ce83      c1d39ce8      go  c1d39ce8_nohash_3.wav  train    102
# happyc1d39ce80   c1d39ce8   happy  c1d39ce8_nohash_0.wav  train    102
# happyc1d39ce81   c1d39ce8   happy  c1d39ce8_nohash_1.wav  train    102
# ninec1d39ce80    c1d39ce8    nine  c1d39ce8_nohash_0.wav  train    102
# ninec1d39ce84    c1d39ce8    nine  c1d39ce8_nohash_4.wav  train    102
# ninec1d39ce81    c1d39ce8    nine  c1d39ce8_nohash_1.wav  train    102
# two28ce0c580     28ce0c58     two  28ce0c58_nohash_0.wav  train   1002
# three28ce0c582   28ce0c58   three  28ce0c58_nohash_2.wav  train   1002
# no28ce0c586      28ce0c58      no  28ce0c58_nohash_6.wav  train   1002
# no28ce0c587      28ce0c58      no  28ce0c58_nohash_7.wav  train   1002
# no28ce0c584      28ce0c58      no  28ce0c58_nohash_4.wav  train   1002
# nine28ce0c584    28ce0c58    nine  28ce0c58_nohash_4.wav  train   1002
#
# [66 rows x 5 columns]

# %% [markdown]
# ### classifier using word-level feature

# %%
sv_word_models = dict.fromkeys(enroll_spks)
for spk in enroll_spks:
    sv_word_models = load_model(sv_config, "models/si_{}_model.pt".format(spk))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-69-177cb39b419d> in <module>()
#       1 sv_word_models = dict.fromkeys(enroll_spks)
#       2 for spk in enroll_spks:
# ----> 3     sv_word_models = load_model(sv_config, "models/si_{}_model.pt".format(spk))
#
# <ipython-input-61-164c4c4ebd1a> in load_model(config, pretrained_path)
#       3
#       4 def load_model(config, pretrained_path):
# ----> 5     pre_state = torch.load(pretrained_path)
#       6     pre_trained_state = {k: v for k, v in pre_state.items()}
#       7
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/serialization.py in load(f, map_location, pickle_module)
#     227     if isinstance(f, str) or (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     228         new_fd = True
# --> 229         f = open(f, 'rb')
#     230     try:
#     231         return _load(f, map_location, pickle_module)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/si_b9f46737_model.pt'

# %%
for spk in enroll_spks:
    for tag in ['train', 'val', 'test']:
        sv_config['{}_manifest'.format(tag)]=os.path.join(manifest_dir,'sv_{}_{}_manifest.csv'.format(spk, tag))
    # universal feature extractor = "si_command_random_model.pt"
    print("training {}'s classifier".format(spk))
    sv_config['output_file'] = "models/sv_word_{}_model.pt".format(spk)
    # now we don't use word-level speaker models
    hk.sv_train(sv_config, spk_model=uni_spk_models[spk], model=sv_models[spk])
# Out:
# ########### training yes word ##########
# train step #1 accuracy: 1.0, loss: 0.7945159077644348
# train step #2 accuracy: 0.875, loss: 0.7682243585586548
# train step #3 accuracy: 0.9375, loss: 0.77701336145401
# train step #4 accuracy: 0.9375, loss: 0.7763561010360718
# train step #5 accuracy: 0.9375, loss: 0.7645391821861267
# train step #6 accuracy: 0.875, loss: 0.7459397315979004
# train step #7 accuracy: 1.0, loss: 0.7509587407112122
# train step #8 accuracy: 0.9375, loss: 0.7348266839981079
# train step #9 accuracy: 0.8125, loss: 0.7189040184020996
# train step #10 accuracy: 1.0, loss: 0.7139837145805359
# train step #11 accuracy: 1.0, loss: 0.6955537796020508
# train step #12 accuracy: 0.875, loss: 0.6853870153427124
# train step #13 accuracy: 1.0, loss: 0.6611524820327759
# train step #14 accuracy: 0.875, loss: 0.6646353006362915
# train step #15 accuracy: 0.8125, loss: 0.6645745635032654
# epoch #0, final dev accuracy: 0.9833333333333333
# saving best model...
# train step #16 accuracy: 1.0, loss: 0.6165439486503601
# train step #17 accuracy: 0.9375, loss: 0.6079253554344177
# train step #18 accuracy: 1.0, loss: 0.577070415019989
# train step #19 accuracy: 0.9375, loss: 0.5844332575798035
# train step #20 accuracy: 0.9375, loss: 0.5702117085456848
# train step #21 accuracy: 0.8125, loss: 0.6066015362739563
# train step #22 accuracy: 0.875, loss: 0.5731850862503052
# train step #23 accuracy: 0.8125, loss: 0.5940837860107422
# train step #24 accuracy: 0.8125, loss: 0.5936858057975769
# train step #25 accuracy: 1.0, loss: 0.48414555191993713
# train step #26 accuracy: 1.0, loss: 0.47577232122421265
# train step #27 accuracy: 0.875, loss: 0.5348708629608154
# train step #28 accuracy: 1.0, loss: 0.45301544666290283
# train step #29 accuracy: 0.9375, loss: 0.47598162293434143
# train step #30 accuracy: 0.9375, loss: 0.46847888827323914
# epoch #1, final dev accuracy: 0.9833333333333333
# train step #31 accuracy: 0.9375, loss: 0.4636380672454834
# train step #32 accuracy: 0.8125, loss: 0.541939914226532
# train step #33 accuracy: 0.875, loss: 0.4892057180404663
# train step #34 accuracy: 0.9375, loss: 0.43257641792297363
# train step #35 accuracy: 0.875, loss: 0.47714903950691223
# train step #36 accuracy: 1.0, loss: 0.3658064603805542
# train step #37 accuracy: 1.0, loss: 0.3598312735557556
# train step #38 accuracy: 0.875, loss: 0.46731969714164734
# train step #39 accuracy: 1.0, loss: 0.3414798378944397
# train step #40 accuracy: 0.875, loss: 0.45685523748397827
# train step #41 accuracy: 0.9375, loss: 0.3882600665092468
# train step #42 accuracy: 0.875, loss: 0.44490814208984375
# train step #43 accuracy: 0.9375, loss: 0.37968552112579346
# train step #44 accuracy: 0.9375, loss: 0.3739832043647766
# train step #45 accuracy: 1.0, loss: 0.2995932102203369
# epoch #2, final dev accuracy: 0.9791666666666666
# train step #46 accuracy: 0.8125, loss: 0.5014533400535583
# train step #47 accuracy: 1.0, loss: 0.29042431712150574
# train step #48 accuracy: 0.875, loss: 0.42706024646759033
# train step #49 accuracy: 0.875, loss: 0.4242717921733856
# train step #50 accuracy: 0.9375, loss: 0.34663301706314087
# train step #51 accuracy: 0.8125, loss: 0.4994567632675171
# train step #52 accuracy: 0.9375, loss: 0.3390137255191803
# train step #53 accuracy: 0.875, loss: 0.4128493666648865
# train step #54 accuracy: 0.875, loss: 0.4134308397769928
# train step #55 accuracy: 1.0, loss: 0.25357261300086975
# train step #56 accuracy: 1.0, loss: 0.24848207831382751
# train step #57 accuracy: 0.875, loss: 0.4108928442001343
# train step #58 accuracy: 1.0, loss: 0.24197597801685333
# train step #59 accuracy: 1.0, loss: 0.23682133853435516
# train step #60 accuracy: 1.0, loss: 0.23448894917964935
# epoch #3, final dev accuracy: 0.9833333333333333
# train step #61 accuracy: 0.9375, loss: 0.31451088190078735
# train step #62 accuracy: 0.9375, loss: 0.3168179988861084
# train step #63 accuracy: 0.9375, loss: 0.3122994899749756
# train step #64 accuracy: 0.9375, loss: 0.30994072556495667
# train step #65 accuracy: 0.8125, loss: 0.49274325370788574
# train step #66 accuracy: 0.9375, loss: 0.3046700954437256
# train step #67 accuracy: 1.0, loss: 0.20914344489574432
# train step #68 accuracy: 0.9375, loss: 0.30115237832069397
# train step #69 accuracy: 0.875, loss: 0.3918069005012512
# train step #70 accuracy: 1.0, loss: 0.20292817056179047
# train step #71 accuracy: 0.875, loss: 0.39284056425094604
# train step #72 accuracy: 0.875, loss: 0.38920560479164124
# train step #73 accuracy: 1.0, loss: 0.19533947110176086
# train step #74 accuracy: 1.0, loss: 0.1925358772277832
# train step #75 accuracy: 0.8125, loss: 0.4856644570827484
# epoch #4, final dev accuracy: 0.9833333333333333
# train step #76 accuracy: 1.0, loss: 0.18824847042560577
# train step #77 accuracy: 1.0, loss: 0.18454265594482422
# train step #78 accuracy: 1.0, loss: 0.1833437830209732
# train step #79 accuracy: 0.875, loss: 0.3869282007217407
# train step #80 accuracy: 1.0, loss: 0.17900122702121735
# train step #81 accuracy: 0.875, loss: 0.3845360279083252
# train step #82 accuracy: 0.9375, loss: 0.28217610716819763
# train step #83 accuracy: 1.0, loss: 0.17369602620601654
# train step #84 accuracy: 0.75, loss: 0.5973974466323853
# train step #85 accuracy: 0.9375, loss: 0.27649837732315063
# train step #86 accuracy: 0.9375, loss: 0.2773746848106384
# train step #87 accuracy: 0.9375, loss: 0.2738897502422333
# train step #88 accuracy: 0.8125, loss: 0.4928531050682068
# train step #89 accuracy: 0.8125, loss: 0.4901692271232605
# train step #90 accuracy: 1.0, loss: 0.16344189643859863
# epoch #5, final dev accuracy: 0.9833333333333333
# train step #91 accuracy: 1.0, loss: 0.1621835082769394
# train step #92 accuracy: 1.0, loss: 0.15985561907291412
# train step #93 accuracy: 0.9375, loss: 0.2697223126888275
# train step #94 accuracy: 0.875, loss: 0.381656676530838
# train step #95 accuracy: 1.0, loss: 0.15645749866962433
# train step #96 accuracy: 0.75, loss: 0.6049885749816895
# train step #97 accuracy: 0.875, loss: 0.3833027482032776
# train step #98 accuracy: 0.8125, loss: 0.49191537499427795
# train step #99 accuracy: 0.875, loss: 0.3810376226902008
# train step #100 accuracy: 0.9375, loss: 0.26597392559051514
# train step #101 accuracy: 1.0, loss: 0.15037858486175537
# train step #102 accuracy: 0.9375, loss: 0.26693353056907654
# train step #103 accuracy: 0.9375, loss: 0.2651853859424591
# train step #104 accuracy: 1.0, loss: 0.1478216052055359
# train step #105 accuracy: 0.9375, loss: 0.2626396417617798
# epoch #6, final dev accuracy: 0.9833333333333333
# train step #106 accuracy: 0.9375, loss: 0.2638803720474243
# train step #107 accuracy: 0.875, loss: 0.3810756504535675
# train step #108 accuracy: 0.8125, loss: 0.4953836500644684
# train step #109 accuracy: 1.0, loss: 0.1431121975183487
# train step #110 accuracy: 0.875, loss: 0.378155380487442
# train step #111 accuracy: 0.9375, loss: 0.2600402534008026
# train step #112 accuracy: 0.9375, loss: 0.2604418098926544
# train step #113 accuracy: 0.9375, loss: 0.25960201025009155
# train step #114 accuracy: 0.9375, loss: 0.2599712312221527
# train step #115 accuracy: 0.9375, loss: 0.2583860158920288
# train step #116 accuracy: 1.0, loss: 0.13790684938430786
# train step #117 accuracy: 0.9375, loss: 0.25710034370422363
# train step #118 accuracy: 0.875, loss: 0.37971231341362
# train step #119 accuracy: 0.875, loss: 0.37854865193367004
# train step #120 accuracy: 1.0, loss: 0.13450805842876434
# Process Process-21075:
# KeyboardInterrupt
# Process Process-21078:
# Process Process-21079:
# Process Process-21074:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-231-102870f084b0> in <module>()
#       6     sv_model = load_model(sv_config, "models/si_{}_model.pt".format('command_random'))
#       7     sv_config['output_file'] = "models/sv_{}_model.pt".format(test_word)
# ----> 8     hk.sv_train(sv_config, spk_model=word_spk_models[spk][pick_words.index(test_word)], model=sv_model)
#
# ~/DL/projects/sv_system/honk_sv/train.py in sv_train(config, spk_model, model)
#     533             model.eval()
#     534             accs = []
# --> 535             for model_in, labels in dev_loader:
#     536                 model_in = Variable(model_in, requires_grad=False)
#     537                 if not config["no_cuda"]:
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __iter__(self)
#     299
#     300     def __iter__(self):
# --> 301         return DataLoaderIter(self)
#     302
#     303     def __len__(self):
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __init__(self, loader)
#     156             for w in self.workers:
#     157                 w.daemon = True  # ensure that the worker exits on process exit
# --> 158                 w.start()
#     159
#     160             if self.pin_memory:
#
# ~/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         _children.add(self)
#
# ~/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/context.py in _Popen(process_obj)
#     221     @staticmethod
#     222     def _Popen(process_obj):
# --> 223         return _default_context.get_context().Process._Popen(process_obj)
#     224
#     225 class DefaultContext(BaseContext):
#
# ~/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/context.py in _Popen(process_obj)
#     275         def _Popen(process_obj):
#     276             from .popen_fork import Popen
# --> 277             return Popen(process_obj)
#     278
#     279     class SpawnProcess(process.BaseProcess):
#
# ~/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      18         sys.stderr.flush()
#      19         self.returncode = None
# ---> 20         self._launch(process_obj)
#      21
#      22     def duplicate_for_child(self, fd):
#
# ~/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      65         code = 1
#      66         parent_r, child_w = os.pipe()
# ---> 67         self.pid = os.fork()
#      68         if self.pid == 0:
#      69             try:
#
# KeyboardInterrupt:
# Process Process-21073:
# Process Process-21080:
# Process Process-21076:
# Process Process-21077:
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     res = self._reader.recv_bytes()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 32, in _worker_loop
#     torch.set_num_threads(1)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 341, in get
#     with self._rlock:
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Process Process-21081:
# Traceback (most recent call last):
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     res = self._reader.recv_bytes()
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/muncok/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
sv_model
# Out:
# logRegModel (
#   (conv1): Conv2d(1, 64, kernel_size=[20, 8], stride=(1, 1))
#   (pool1): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (conv2): Conv2d(64, 64, kernel_size=[10, 4], stride=(1, 1))
#   (pool2): MaxPool2d (size=(1, 1), stride=(1, 1), dilation=(1, 1))
#   (bottleneck): Linear (26624 -> 256)
#   (output): Linear (256 -> 2000)
#   (dropout): Dropout (p = 0.5)
#   (linear): Linear (1 -> 1)
# )
