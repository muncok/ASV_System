# %%
import librosa
import librosa.display
import IPython.display as ipd

# %%
file_path = "./test_overay.wav"
x, sr = librosa.load(file_path, sr=16000)
ipd.Audio(data=x,rate=sr)  # clipt to 8000samples
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from pydub import AudioSegment
sound1 = "/home/muncok/DL/dataset/SV_sets/reddots_r2015q4_v1/wav/f0001/20150302171020760_f0001_58.wav"
sound2 = "/home/muncok/DL/dataset/SV_sets/reddots_r2015q4_v1/wav/m0006/20150209085337583_m0006_34.wav"
sound1 = AudioSegment.from_file(sound1)
sound2 = AudioSegment.from_file(sound2)

# %%
sound1
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
sound2
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
played_togther = sound1.overlay(sound2, position=1000)

# %%
played_togther
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>
